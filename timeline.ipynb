# %% [markdown]
# <a href="https://colab.research.google.com/github/kozyreviva/Data_Science/blob/main/timeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
# ​
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
# ​
# Вам нужно:
# ​
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
# ​

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Подключим библиотеки.

# %%
#библиотеки
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# Скачаем датасет и сохраним в переменную.

# %%
#скачивание датасета
try:
  df = pd.read_csv("/datasets/taxi.csv", index_col = [0],parse_dates = [0])
except:
  df = pd.read_csv("taxi.csv", index_col = [0], parse_dates = [0])

# %% [markdown]
# Выведем датасет и посмотрем краткую информацию.

# %%
#вывод таблицы
df.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
#информация о таблице
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
#размер таблицы
df.shape
# Out:
# (26496, 1)

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# Отсортируем таблицу и сгруппируем данные по часу.

# %%
#сортировка датафрейма
df.sort_index(inplace=True)
#ресемплирование
df = df.resample('1H').sum()

# %% [markdown]
# Проведем небольшой анализ данных.

# %% [markdown]
# Т.к данных много для наглядности ресемплируем данные по 6 часов и посмотрим на график

# %%
fig = px.line(df.resample("6H").sum(), title = "Количество вызовов")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="221aebe2-af62-49d2-9916-0d8ed5baf9ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("221aebe2-af62-49d2-9916-0d8ed5baf9ff")) {                    Plotly.newPlot(                        "221aebe2-af62-49d2-9916-0d8ed5baf9ff",                        [{"hovertemplate":"variable=num_orders<br>datetime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"num_orders","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"num_orders","orientation":"v","showlegend":true,"x":["2018-03-01T00:00:00","2018-03-01T06:00:00","2018-03-01T12:00:00","2018-03-01T18:00:00","2018-03-02T00:00:00","2018-03-02T06:00:00","2018-03-02T12:00:00","2018-03-02T18:00:00","2018-03-03T00:00:00","2018-03-03T06:00:00","2018-03-03T12:00:00","2018-03-03T18:00:00","2018-03-04T00:00:00","2018-03-04T06:00:00","2018-03-04T12:00:00","2018-03-04T18:00:00","2018-03-05T00:00:00","2018-03-05T06:00:00","2018-03-05T12:00:00","2018-03-05T18:00:00","2018-03-06T00:00:00","2018-03-06T06:00:00","2018-03-06T12:00:00","2018-03-06T18:00:00","2018-03-07T00:00:00","2018-03-07T06:00:00","2018-03-07T12:00:00","2018-03-07T18:00:00","2018-03-08T00:00:00","2018-03-08T06:00:00","2018-03-08T12:00:00","2018-03-08T18:00:00","2018-03-09T00:00:00","2018-03-09T06:00:00","2018-03-09T12:00:00","2018-03-09T18:00:00","2018-03-10T00:00:00","2018-03-10T06:00:00","2018-03-10T12:00:00","2018-03-10T18:00:00","2018-03-11T00:00:00","2018-03-11T06:00:00","2018-03-11T12:00:00","2018-03-11T18:00:00","2018-03-12T00:00:00","2018-03-12T06:00:00","2018-03-12T12:00:00","2018-03-12T18:00:00","2018-03-13T00:00:00","2018-03-13T06:00:00","2018-03-13T12:00:00","2018-03-13T18:00:00","2018-03-14T00:00:00","2018-03-14T06:00:00","2018-03-14T12:00:00","2018-03-14T18:00:00","2018-03-15T00:00:00","2018-03-15T06:00:00","2018-03-15T12:00:00","2018-03-15T18:00:00","2018-03-16T00:00:00","2018-03-16T06:00:00","2018-03-16T12:00:00","2018-03-16T18:00:00","2018-03-17T00:00:00","2018-03-17T06:00:00","2018-03-17T12:00:00","2018-03-17T18:00:00","2018-03-18T00:00:00","2018-03-18T06:00:00","2018-03-18T12:00:00","2018-03-18T18:00:00","2018-03-19T00:00:00","2018-03-19T06:00:00","2018-03-19T12:00:00","2018-03-19T18:00:00","2018-03-20T00:00:00","2018-03-20T06:00:00","2018-03-20T12:00:00","2018-03-20T18:00:00","2018-03-21T00:00:00","2018-03-21T06:00:00","2018-03-21T12:00:00","2018-03-21T18:00:00","2018-03-22T00:00:00","2018-03-22T06:00:00","2018-03-22T12:00:00","2018-03-22T18:00:00","2018-03-23T00:00:00","2018-03-23T06:00:00","2018-03-23T12:00:00","2018-03-23T18:00:00","2018-03-24T00:00:00","2018-03-24T06:00:00","2018-03-24T12:00:00","2018-03-24T18:00:00","2018-03-25T00:00:00","2018-03-25T06:00:00","2018-03-25T12:00:00","2018-03-25T18:00:00","2018-03-26T00:00:00","2018-03-26T06:00:00","2018-03-26T12:00:00","2018-03-26T18:00:00","2018-03-27T00:00:00","2018-03-27T06:00:00","2018-03-27T12:00:00","2018-03-27T18:00:00","2018-03-28T00:00:00","2018-03-28T06:00:00","2018-03-28T12:00:00","2018-03-28T18:00:00","2018-03-29T00:00:00","2018-03-29T06:00:00","2018-03-29T12:00:00","2018-03-29T18:00:00","2018-03-30T00:00:00","2018-03-30T06:00:00","2018-03-30T12:00:00","2018-03-30T18:00:00","2018-03-31T00:00:00","2018-03-31T06:00:00","2018-03-31T12:00:00","2018-03-31T18:00:00","2018-04-01T00:00:00","2018-04-01T06:00:00","2018-04-01T12:00:00","2018-04-01T18:00:00","2018-04-02T00:00:00","2018-04-02T06:00:00","2018-04-02T12:00:00","2018-04-02T18:00:00","2018-04-03T00:00:00","2018-04-03T06:00:00","2018-04-03T12:00:00","2018-04-03T18:00:00","2018-04-04T00:00:00","2018-04-04T06:00:00","2018-04-04T12:00:00","2018-04-04T18:00:00","2018-04-05T00:00:00","2018-04-05T06:00:00","2018-04-05T12:00:00","2018-04-05T18:00:00","2018-04-06T00:00:00","201 ...

# %% [markdown]
# Посмотрим на тренд и сезонность. Сохраним их в отдельные столбцы.

# %%
#создание объекта структуры с результатами применения функции
decomposed = seasonal_decompose(df)
#создание столбцов
df["trand"] = decomposed.trend
df["season"] = decomposed.seasonal

# %% [markdown]
# Вывод тренда.

# %%
fig = px.line(df["trand"], title = "Тренд")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d0eb6f5b-aea0-4d29-afc7-91d21abbe8e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0eb6f5b-aea0-4d29-afc7-91d21abbe8e1")) {                    Plotly.newPlot(                        "d0eb6f5b-aea0-4d29-afc7-91d21abbe8e1",                        [{"hovertemplate":"variable=trand<br>datetime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"trand","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"trand","showlegend":true,"x":["2018-03-01T00:00:00","2018-03-01T01:00:00","2018-03-01T02:00:00","2018-03-01T03:00:00","2018-03-01T04:00:00","2018-03-01T05:00:00","2018-03-01T06:00:00","2018-03-01T07:00:00","2018-03-01T08:00:00","2018-03-01T09:00:00","2018-03-01T10:00:00","2018-03-01T11:00:00","2018-03-01T12:00:00","2018-03-01T13:00:00","2018-03-01T14:00:00","2018-03-01T15:00:00","2018-03-01T16:00:00","2018-03-01T17:00:00","2018-03-01T18:00:00","2018-03-01T19:00:00","2018-03-01T20:00:00","2018-03-01T21:00:00","2018-03-01T22:00:00","2018-03-01T23:00:00","2018-03-02T00:00:00","2018-03-02T01:00:00","2018-03-02T02:00:00","2018-03-02T03:00:00","2018-03-02T04:00:00","2018-03-02T05:00:00","2018-03-02T06:00:00","2018-03-02T07:00:00","2018-03-02T08:00:00","2018-03-02T09:00:00","2018-03-02T10:00:00","2018-03-02T11:00:00","2018-03-02T12:00:00","2018-03-02T13:00:00","2018-03-02T14:00:00","2018-03-02T15:00:00","2018-03-02T16:00:00","2018-03-02T17:00:00","2018-03-02T18:00:00","2018-03-02T19:00:00","2018-03-02T20:00:00","2018-03-02T21:00:00","2018-03-02T22:00:00","2018-03-02T23:00:00","2018-03-03T00:00:00","2018-03-03T01:00:00","2018-03-03T02:00:00","2018-03-03T03:00:00","2018-03-03T04:00:00","2018-03-03T05:00:00","2018-03-03T06:00:00","2018-03-03T07:00:00","2018-03-03T08:00:00","2018-03-03T09:00:00","2018-03-03T10:00:00","2018-03-03T11:00:00","2018-03-03T12:00:00","2018-03-03T13:00:00","2018-03-03T14:00:00","2018-03-03T15:00:00","2018-03-03T16:00:00","2018-03-03T17:00:00","2018-03-03T18:00:00","2018-03-03T19:00:00","2018-03-03T20:00:00","2018-03-03T21:00:00","2018-03-03T22:00:00","2018-03-03T23:00:00","2018-03-04T00:00:00","2018-03-04T01:00:00","2018-03-04T02:00:00","2018-03-04T03:00:00","2018-03-04T04:00:00","2018-03-04T05:00:00","2018-03-04T06:00:00","2018-03-04T07:00:00","2018-03-04T08:00:00","2018-03-04T09:00:00","2018-03-04T10:00:00","2018-03-04T11:00:00","2018-03-04T12:00:00","2018-03-04T13:00:00","2018-03-04T14:00:00","2018-03-04T15:00:00","2018-03-04T16:00:00","2018-03-04T17:00:00","2018-03-04T18:00:00","2018-03-04T19:00:00","2018-03-04T20:00:00","2018-03-04T21:00:00","2018-03-04T22:00:00","2018-03-04T23:00:00","2018-03-05T00:00:00","2018-03-05T01:00:00","2018-03-05T02:00:00","2018-03-05T03:00:00","2018-03-05T04:00:00","2018-03-05T05:00:00","2018-03-05T06:00:00","2018-03-05T07:00:00","2018-03-05T08:00:00","2018-03-05T09:00:00","2018-03-05T10:00:00","2018-03-05T11:00:00","2018-03-05T12:00:00","2018-03-05T13:00:00","2018-03-05T14:00:00","2018-03-05T15:00:00","2018-03-05T16:00:00","2018-03-05T17:00:00","2018-03-05T18:00:00","2018-03-05T19:00:00","2018-03-05T20:00:00","2018-03-05T21:00:00","2018-03-05T22:00:00","2018-03-05T23:00:00","2018-03-06T00:00:00","2018-03-06T01:00:00","2018-03-06T02:00:00","2018-03-06T03:00:00","2018-03-06T04:00:00","2018-03-06T05:00:00","2018-03-06T06:00:00","2018-03-06T07:00:00","2018-03-06T08:00:00","2018-03-06T09:00:00","2018-03-06T10:00:00","2018-03-06T11:00:00","2018-03-06T12:00:00","2018-03-06T13:00:00","2018-03-06T14:00:00","2018-03-06T15:00:00","2018-03-06T16:00:00","2018-03-06T17:00:00","2018-03-06T18:00:00","2018-03-06T19:00:00","2018-03-06T20:00:00","2018-03-06T21:00:00","2018-03-06T22:00:00","2018-03-06T23:00:00","2018-03-07T00:00:00","2018-03-07T01:00:00","2018-03-07T02: ...

# %% [markdown]
# Вывод сезонности. Возьмем суточный интервал.

# %%
fig = px.line(df["2018-03-01":"2018-03-02"]["season"], title = "Сезонность")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="48dfd54f-26c8-4a4c-8f2c-071b4e40bd15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48dfd54f-26c8-4a4c-8f2c-071b4e40bd15")) {                    Plotly.newPlot(                        "48dfd54f-26c8-4a4c-8f2c-071b4e40bd15",                        [{"hovertemplate":"variable=season<br>datetime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"season","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"season","orientation":"v","showlegend":true,"x":["2018-03-01T00:00:00","2018-03-01T01:00:00","2018-03-01T02:00:00","2018-03-01T03:00:00","2018-03-01T04:00:00","2018-03-01T05:00:00","2018-03-01T06:00:00","2018-03-01T07:00:00","2018-03-01T08:00:00","2018-03-01T09:00:00","2018-03-01T10:00:00","2018-03-01T11:00:00","2018-03-01T12:00:00","2018-03-01T13:00:00","2018-03-01T14:00:00","2018-03-01T15:00:00","2018-03-01T16:00:00","2018-03-01T17:00:00","2018-03-01T18:00:00","2018-03-01T19:00:00","2018-03-01T20:00:00","2018-03-01T21:00:00","2018-03-01T22:00:00","2018-03-01T23:00:00","2018-03-02T00:00:00","2018-03-02T01:00:00","2018-03-02T02:00:00","2018-03-02T03:00:00","2018-03-02T04:00:00","2018-03-02T05:00:00","2018-03-02T06:00:00","2018-03-02T07:00:00","2018-03-02T08:00:00","2018-03-02T09:00:00","2018-03-02T10:00:00","2018-03-02T11:00:00","2018-03-02T12:00:00","2018-03-02T13:00:00","2018-03-02T14:00:00","2018-03-02T15:00:00","2018-03-02T16:00:00","2018-03-02T17:00:00","2018-03-02T18:00:00","2018-03-02T19:00:00","2018-03-02T20:00:00","2018-03-02T21:00:00","2018-03-02T22:00:00","2018-03-02T23:00:00"],"xaxis":"x","y":[60.248112097753484,20.177073846387373,28.982743245294472,17.885407179720705,2.79114488463874,-41.56302178202793,-59.182671144505164,-55.104460761991504,-11.212839632665451,4.443581132361872,8.759268746205224,-2.133376973284758,-16.72160557073467,-13.352411581663628,-9.191664769277473,3.731832498482089,29.60410025804493,7.920015558591379,-15.527958029751062,-7.124269505160898,-2.6965600333940483,10.670243245294477,13.596814283545845,25.000502808136005,60.248112097753484,20.177073846387373,28.982743245294472,17.885407179720705,2.79114488463874,-41.56302178202793,-59.182671144505164,-55.104460761991504,-11.212839632665451,4.443581132361872,8.759268746205224,-2.133376973284758,-16.72160557073467,-13.352411581663628,-9.191664769277473,3.731832498482089,29.60410025804493,7.920015558591379,-15.527958029751062,-7.124269505160898,-2.6965600333940483,10.670243245294477,13.596814283545845,25.000502808136005],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}]," ...

# %% [markdown]
# Построим график дневной сезонности.

# %%
fig = px.line(df["2018-03-01":"2018-03-07"]["season"], title = "Сезонность")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7832efac-9a71-4ea9-8819-27111ab1c25c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7832efac-9a71-4ea9-8819-27111ab1c25c")) {                    Plotly.newPlot(                        "7832efac-9a71-4ea9-8819-27111ab1c25c",                        [{"hovertemplate":"variable=season<br>datetime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"season","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"season","orientation":"v","showlegend":true,"x":["2018-03-01T00:00:00","2018-03-01T01:00:00","2018-03-01T02:00:00","2018-03-01T03:00:00","2018-03-01T04:00:00","2018-03-01T05:00:00","2018-03-01T06:00:00","2018-03-01T07:00:00","2018-03-01T08:00:00","2018-03-01T09:00:00","2018-03-01T10:00:00","2018-03-01T11:00:00","2018-03-01T12:00:00","2018-03-01T13:00:00","2018-03-01T14:00:00","2018-03-01T15:00:00","2018-03-01T16:00:00","2018-03-01T17:00:00","2018-03-01T18:00:00","2018-03-01T19:00:00","2018-03-01T20:00:00","2018-03-01T21:00:00","2018-03-01T22:00:00","2018-03-01T23:00:00","2018-03-02T00:00:00","2018-03-02T01:00:00","2018-03-02T02:00:00","2018-03-02T03:00:00","2018-03-02T04:00:00","2018-03-02T05:00:00","2018-03-02T06:00:00","2018-03-02T07:00:00","2018-03-02T08:00:00","2018-03-02T09:00:00","2018-03-02T10:00:00","2018-03-02T11:00:00","2018-03-02T12:00:00","2018-03-02T13:00:00","2018-03-02T14:00:00","2018-03-02T15:00:00","2018-03-02T16:00:00","2018-03-02T17:00:00","2018-03-02T18:00:00","2018-03-02T19:00:00","2018-03-02T20:00:00","2018-03-02T21:00:00","2018-03-02T22:00:00","2018-03-02T23:00:00","2018-03-03T00:00:00","2018-03-03T01:00:00","2018-03-03T02:00:00","2018-03-03T03:00:00","2018-03-03T04:00:00","2018-03-03T05:00:00","2018-03-03T06:00:00","2018-03-03T07:00:00","2018-03-03T08:00:00","2018-03-03T09:00:00","2018-03-03T10:00:00","2018-03-03T11:00:00","2018-03-03T12:00:00","2018-03-03T13:00:00","2018-03-03T14:00:00","2018-03-03T15:00:00","2018-03-03T16:00:00","2018-03-03T17:00:00","2018-03-03T18:00:00","2018-03-03T19:00:00","2018-03-03T20:00:00","2018-03-03T21:00:00","2018-03-03T22:00:00","2018-03-03T23:00:00","2018-03-04T00:00:00","2018-03-04T01:00:00","2018-03-04T02:00:00","2018-03-04T03:00:00","2018-03-04T04:00:00","2018-03-04T05:00:00","2018-03-04T06:00:00","2018-03-04T07:00:00","2018-03-04T08:00:00","2018-03-04T09:00:00","2018-03-04T10:00:00","2018-03-04T11:00:00","2018-03-04T12:00:00","2018-03-04T13:00:00","2018-03-04T14:00:00","2018-03-04T15:00:00","2018-03-04T16:00:00","2018-03-04T17:00:00","2018-03-04T18:00:00","2018-03-04T19:00:00","2018-03-04T20:00:00","2018-03-04T21:00:00","2018-03-04T22:00:00","2018-03-04T23:00:00","2018-03-05T00:00:00","2018-03-05T01:00:00","2018-03-05T02:00:00","2018-03-05T03:00:00","2018-03-05T04:00:00","2018-03-05T05:00:00","2018-03-05T06:00:00","2018-03-05T07:00:00","2018-03-05T08:00:00","2018-03-05T09:00:00","2018-03-05T10:00:00","2018-03-05T11:00:00","2018-03-05T12:00:00","2018-03-05T13:00:00","2018-03-05T14:00:00","2018-03-05T15:00:00","2018-03-05T16:00:00","2018-03-05T17:00:00","2018-03-05T18:00:00","2018-03-05T19:00:00","2018-03-05T20:00:00","2018-03-05T21:00:00","2018-03-05T22:00:00","2018-03-05T23:00:00","2018-03-06T00:00:00","2018-03-06T01:00:00","2018-03-06T02:00:00","2018-03-06T03:00:00","2018-03-06T04:00:00","2018-03-06T05:00:00","2018-03-06T06:00:00","2018-03-06T07:00:00","2018-03-06T08:00:00","2018-03-06T09:00:00","2018-03-06T10:00:00","2018-03-06T11:00:00","2018-03-06T12:00:00","2018-03-06T13:00:00","2018-03-06T14:00:00","2018-03-06T15:00:00","2018-03-06T16:00:00","2018-03-06T17:00:00","2018-03-06T18:00:00","2018-03-06T19:00:00","2018-03-06T20:00:00","2018-03-06T21:00:00","2018-03-06T22:00:00","2018-03-06T23:00:00","2018-03-07T00:00:00","2018-03-07T01:0 ...

# %% [markdown]
# **Выводы:**
#
# Данные в таблице содержаться всего за пол года, поэтому с точностью нельзя сказать что у нас имеется восходящий тренда за счет роста компании. Возможно количество закаова растёт в летний период.
# Суточная сезонность показывает увеличение заказов в полночь и падение к 6 часам. Дневная сезонность не показыевает различий среди недели.

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# Создадим функцию которая добавляет в датафрейм столбцы с годом, месяцем, днём и днём недели. Также добавим столбцы со сдвигами и скользящим средним.

# %%
#функция добавления столбцов
def make_features(data, lag, rolling_mean_size):
    data["hour"] = data.index.day
    data["dayofweek"] = data.index.dayofweek

    for i in range(1, lag+1):
        data["lag_{}",format(i)] = data["num_orders"].shift(i)
    
    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# %% [markdown]
# Применение этой функции необходимо для обучения модели. Она предоставляет больше данных.
#
# Применим функцию.

# %%
#применение функции
make_features(df, 2, 24)

# %% [markdown]
# Удалим строки с пропусками образовавшиеся в ходе сдвига данных.

# %%
#удаление строк
df = df.dropna(axis = 0)

# %% [markdown]
# Разделим таблицу на обучающую и тестовую выборки при этом данные не смешиваем.
# Разделим на признаки.

# %%
#разделение на выборки
train, test = train_test_split(df, shuffle = False, test_size = 0.1)

#разделение на признаки
features_train = train.drop("num_orders",axis = 1)
target_train = train["num_orders"]

features_test = test.drop("num_orders",axis = 1)
target_test = test["num_orders"]

# %% [markdown]
# Создадим валидатор для временных рядов.

# %%
#создание временного валидатора
ts = TimeSeriesSplit(n_splits = 8, test_size = 3)

# %% [markdown]
# Протестируем модели кросс-валидацией.

# %%
# %%time
#модель дерева решений
model_tree = DecisionTreeRegressor(random_state = 12345)

params = [{"max_depth": np.arange(1,21,2)}]
gs_tree = GridSearchCV(estimator = model_tree,
                      param_grid=params,
                      scoring="neg_root_mean_squared_error",
                      cv=ts)
gs_tree.fit(features_train.values, target_train.values)
print(gs_tree.best_params_)
print(np.abs(gs_tree.score(features_train.values, target_train.values)))
# Out:
# {'max_depth': 3}
# 26.13391868149803
# CPU times: user 1.41 s, sys: 10.4 ms, total: 1.42 s
# Wall time: 1.41 s

# %%
# %%time
#модель случайного леса
model_rf = RandomForestRegressor(random_state = 12345)

params = [{"n_estimators": np.arange(10,51,10),
      "max_depth": np.arange(1,16,2)}]
gs_rf = GridSearchCV(estimator = model_rf,
                      param_grid=params,
                      scoring="neg_root_mean_squared_error",
                      cv=ts)
gs_rf.fit(features_train.values, target_train.values)
print(gs_rf.best_params_)
print(np.abs(gs_rf.score(features_train.values, target_train.values)))

# %%
# %%time
#линейная регрессия
linear_model = LinearRegression()

scores = cross_val_score(linear_model, features_train.values, target_train.values, scoring="neg_root_mean_squared_error", cv = ts)

print(np.abs(scores.mean()))

# %%
# %%time
#модель LightGBM
model_LGBM = LGBMRegressor()

params = [{"n_estimators": np.arange(10,31,10),
      "max_depth": np.arange(1,11,2)}]
gs_LGBM = GridSearchCV(estimator = model_LGBM,
                      param_grid=params,
                      scoring="neg_root_mean_squared_error",
                      cv=ts)
gs_LGBM.fit(features_train.values, target_train.values)
print("LightGBM")
print(gs_LGBM.best_params_)
print(np.abs(gs_LGBM.score(features_train.values, target_train.values)))

# %% [markdown]
# ## Проверка моделей

# %%
xrange = target_test[:"2018-08-16"].index

# %% [markdown]
# Проверим модели на тестовой выборке.

# %%
#модель дерева решений
print("Дерево решений")
print("RMSE:",np.abs(gs_tree.score(features_test.values, target_test.values)))

# %%
predictions = gs_tree.predict(features_test)
fig = go.Figure()
fig.add_trace(go.Scatter(y = target_test, x = xrange,  name = "Реальные",mode='lines',))
fig.add_trace(go.Scatter(y = predictions, x = xrange, name = "Предсказанные",mode='lines',))
fig.update_layout(
    title="Предсказания дерева решений",
    xaxis_title="Дата и время",
    yaxis_title="Количество заказов",
    legend_title="Данные")
fig.show()

# %%
#модель рандомного леса
print("Рандомный лес")
print("RMSE:",np.abs(gs_rf.score(features_test.values, target_test.values)))

# %%
predictions = gs_rf.predict(features_test)
fig = go.Figure()
fig.add_trace(go.Scatter(y = target_test, x = xrange, name = "Реальные",mode='lines',))
fig.add_trace(go.Scatter(y = predictions, x = xrange, name = "Предсказанные",mode='lines',))
fig.update_layout(
    title="Предсказания рандомного леса",
    xaxis_title="Дата и время",
    yaxis_title="Количество заказов",
    legend_title="Данные")
fig.show()

# %%
#модель линейной регрессии
linear_model.fit(features_train.values,target_train.values)
predictions = linear_model.predict(features_test.values)
print("Линейная регрессия")
print("RMSE:",np.sqrt(mean_squared_error(target_test.values, predictions)))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(y =target_test, x = xrange, name = "Реальные",mode='lines',))
fig.add_trace(go.Scatter(y =predictions, x = xrange, name = "Предсказанные",mode='lines',))
fig.update_layout(
    title="Предсказания линейной регрессии",
    xaxis_title="Дата и время",
    yaxis_title="Количество заказов",
    legend_title="Данные")
fig.show()

# %%
#модель LightGBM
print("LightGBM")
print("RMSE:",np.abs(gs_LGBM.score(features_test.values, target_test.values)))

# %%
predictions = gs_LGBM.predict(features_test)
fig = go.Figure()
fig.add_trace(go.Scatter(y =target_test, x = xrange, name = "Реальные",mode='lines',))
fig.add_trace(go.Scatter(y =predictions, x = xrange, name = "Предсказанные",mode='lines',))
fig.update_layout(
    title="Предсказания LightGBM",
    xaxis_title="Дата и время",
    yaxis_title="Количество заказов",
    legend_title="Данные")
fig.show()

# %% [markdown]
# **Вывод:**
# Модель линейной регрессии дала лучшие результаты по сравнению с другими моделями. НО, если рассматривать данные на графиках, видно что модель LightGBM показывает наибольшую идентичность с реальными данными, а предсказания линейной регрессии расположились более сглаженно. Поэтому, модель lightGBM возможно имеет большую предсказательную ценность.
